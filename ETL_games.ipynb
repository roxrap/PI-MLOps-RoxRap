# %%
import pandas as pd
import numpy as np
import os
import json

# %%
# Se abre el archivo JSON y se lee línea por línea. Cada línea se convierte de JSON a un diccionario de Python utilizando json.loads(), y el diccionario resultante se agrega a la lista filas_games.
filas_games = []
with open(r'C:\Users\ROXANA\Downloads\04-2024\lanzamiento\Roxana\Datasets\output_steam_games.json') as f:
    for line in f.readlines():
        data = json.loads(line)
        filas_games.append(data)

# Se utiliza la lista de diccionarios filas_games para crear un DataFrame de pandas llamado df_games. Cada diccionario en la lista representa una fila en el DataFrame.
df_games = pd.DataFrame(filas_games)
df_games
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  object
#  11  id            32133 non-null  object
#  12  developer     28836 non-null  object
# dtypes: object(13)
# memory usage: 11.9+ MB

# %%
# Eliminar filas con todos los valores nulos
df_games = df_games.dropna(how='all').reset_index(drop=True)
df_games.shape
# Out:
# (32135, 13)

# %%
# Se filtran las filas duplicadas
duplicated_rows = df_games[df_games.duplicated(subset='id', keep=False)]
duplicated_rows
# Out:
#                                                publisher               genres  \
# 74                                                   NaN                  NaN
# 13894                                 Bethesda Softworks             [Action]
# 14573                                 Bethesda Softworks             [Action]
# 30961  Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
#
#                                              app_name  \
# 74                                                NaN
# 13894                Wolfenstein II: The New Colossus
# 14573                Wolfenstein II: The New Colossus
# 30961  Batman: Arkham City - Game of the Year Edition
#
#                                                 title  \
# 74                                                NaN
# 13894                Wolfenstein II: The New Colossus
# 14573                Wolfenstein II: The New Colossus
# 30961  Batman: Arkham City - Game of the Year Edition
#
# ...

# %%
# se eliminan los index duplicados
index_a_eliminar = [74, 13894, 14573, 30961]
df_games = df_games.drop(index_a_eliminar)

# %%
#transformar la columna de fecha
df_games['release_date'].value_counts()
# Out:
# release_date
# 2012-10-16    100
# 2017-08-31     92
# 2017-09-26     89
# 2017-06-21     82
# 2017-07-25     78
#              ...
# 1988-04-16      1
# 2013-08-24      1
# 2011-05-07      1
# 2010-08-21      1
# 2018-10-01      1
# Name: count, Length: 3582, dtype: int64

# %%
# Crea columna nueva con el año
df_games['release_date'] = pd.to_datetime(df_games['release_date'], format='%Y-%m-%d', errors='coerce')

# %%
df_games['release_date']
# Out:
# 0       2018-01-04
# 1       2018-01-04
# 2       2017-07-24
# 3       2017-12-07
# 4              NaT
#            ...
# 32130   2018-01-04
# 32131   2018-01-04
# 32132   2018-01-04
# 32133   2017-09-02
# 32134          NaT
# Name: release_date, Length: 32131, dtype: datetime64[ns]

# %%
#relleno los valores Nan con 0 para poder pasar a int
df_games['release_year'] = df_games['release_date'].dt.year.fillna(0).astype(int)

# %%
df_games['release_year']
# Out:
# 0        2018
# 1        2018
# 2        2017
# 3        2017
# 4           0
#          ...
# 32130    2018
# 32131    2018
# 32132    2018
# 32133    2017
# 32134       0
# Name: release_year, Length: 32131, dtype: int32

# %%
df_games.drop('release_date', axis=1, inplace=True) #elimino la columna 'release_date' ya q es reemplazada por 'release_year'

# %%
data=df_games['price'].unique()  #busco los str en los prcios
data[np.array([isinstance(x, str) for x in data])]
# Out:
# array(['Free To Play', 'Free to Play', 'Free', 'Free Demo',
#        'Play for Free!', 'Install Now', 'Play WARMACHINE: Tactics Demo',
#        'Free Mod', 'Install Theme', 'Third-party', 'Play Now',
#        'Free HITMAN™ Holiday Pack', 'Play the Demo',
#        'Starting at $499.00', 'Starting at $449.00', 'Free to Try',
#        'Free Movie', 'Free to Use'], dtype=object)

# %%
# Reemplazar los valores STR' con 0
df_games['price'] = df_games['price'].replace(['Free To Play', 'Free to Play', 'Free', 'Free Demo',
       'Play for Free!', 'Install Now', 'Play WARMACHINE: Tactics Demo',
       'Free Mod', 'Install Theme', 'Third-party', 'Play Now',
       'Free HITMAN™ Holiday Pack', 'Play the Demo',
       'Starting at $499.00', 'Starting at $449.00', 'Free to Try',
       'Free Movie', 'Free to Use'], float('0'))

# Convertir la columna a tipo float
df_games['price'] = df_games['price'].astype(float)
# Out:
# C:\Users\ROXANA\AppData\Local\Temp\ipykernel_7824\1924414085.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_games['price'] = df_games['price'].replace(['Free To Play', 'Free to Play', 'Free', 'Free Demo',

# %%
df_games['price']
# Out:
# 0        4.99
# 1        0.00
# 2        0.00
# 3        0.99
# 4        2.99
#          ...
# 32130    1.99
# 32131    4.99
# 32132    1.99
# 32133    4.99
# 32134    4.99
# Name: price, Length: 32131, dtype: float64

# %%
# Se rellenan los nulos
df_relleno = df_games[['publisher', 'app_name', 'title', 'developer']].fillna('Sin datos')

# %%
# Se borran las columnas originales y se concatenan las rellenas con todo el dataframe
df_games = pd.concat([df_games.drop(['publisher', 'app_name', 'title', 'developer'], axis=1), df_relleno], axis=1)
df_games.head()
# Out:
#                                               genres  \
# 0      [Action, Casual, Indie, Simulation, Strategy]
# 1               [Free to Play, Indie, RPG, Strategy]
# 2  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                        [Action, Adventure, Casual]
# 4                                                NaN
#
#                                                  url  \
# 0  http://store.steampowered.com/app/761140/Lost_...
# 1  http://store.steampowered.com/app/643980/Ironb...
# 2  http://store.steampowered.com/app/670290/Real_...
# 3     http://store.steampowered.com/app/767400/2222/
# 4  http://store.steampowered.com/app/773570/Log_C...
#
#                                                 tags  \
# 0      [Strategy, Action, Indie, Casual, Simulation]
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...
# 2  [Free to Play, Simulation, Sports, Casual, Ind...
# 3                        [Action, Adventure, Casual]
# ...

# %% [markdown]
# Este código se encarga de descomponer las listas o conjuntos anidados en la columna 'genres' en filas individuales mediante explode, elimina las filas que contienen valores nulos en 'genres' y muestra las primeras filas del DataFrame resultante.

# %%
df_games = df_games.explode('genres')
df_games = df_games.dropna(subset=['genres'])
df_games.head()
# Out:
#        genres                                                url  \
# 0      Action  http://store.steampowered.com/app/761140/Lost_...
# 0      Casual  http://store.steampowered.com/app/761140/Lost_...
# 0       Indie  http://store.steampowered.com/app/761140/Lost_...
# 0  Simulation  http://store.steampowered.com/app/761140/Lost_...
# 0    Strategy  http://store.steampowered.com/app/761140/Lost_...
#
#                                             tags  \
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
#
#                                          reviews_url            specs  price  \
# 0  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]   4.99
# 0  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]   4.99
# ...

# %%
#elimino columnas q no voy a usar
df_games = df_games.drop(['tags', 'specs', 'url', 'reviews_url'], axis=1)
df_games.columns
# Out:
# Index(['genres', 'price', 'early_access', 'id', 'release_year', 'publisher',
#        'app_name', 'title', 'developer'],
#       dtype='object')

# %%
# Verificar si hay valores nulos en las columnas especificadas
columnas_verificar = ['genres', 'price', 'early_access', 'id', 'release_year', 'publisher', 'app_name', 'title', 'developer']
nulos = df_games[columnas_verificar].isnull().any()
nulos
# Out:
# genres          False
# price           False
# early_access    False
# id              False
# release_year    False
# publisher       False
# app_name        False
# title           False
# developer       False
# dtype: bool

# %%
df_games.to_csv(os.path.join(r'C:\Users\ROXANA\Downloads\04-2024\lanzamiento\Roxana\Datasets', 'games_limpios.csv'), index=False)
